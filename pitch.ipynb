# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
from highlight_text import fig_text, ax_text
# We'll only use a vertical pitch for this tutorial
from mplsoccer import VerticalPitch, FontManager, Pitch
import json

URL3 = 'https://github.com/VanillaandCream/Catamaran-Tamil/blob/master/Fonts/Catamaran-Medium.ttf?raw=true'
catamaran2 = FontManager(URL3)
URL = 'https://github.com/google/fonts/blob/main/ofl/fjallaone/FjallaOne-Regular.ttf?raw=true'
robotto_regular = FontManager(URL)
URL2 = 'https://github.com/VanillaandCream/Catamaran-Tamil/blob/master/Fonts/Catamaran-ExtraBold.ttf?raw=true'
catamaran = FontManager(URL2)

# %%
pitch = Pitch(pitch_type = "opta",label=True)
pitch.dim
# Out:
# FixedDims(pitch_width=68.0, pitch_length=105.0, invert_y=False, origin_center=False, pad_default=4, pad_multiplier=1, aspect_equal=False, left=0.0, right=100.0, bottom=0.0, top=100.0, aspect=0.6476190476190476, width=100.0, length=100.0, center_width=50.0, center_length=50.0, pitch_extent=array([  0., 100.,   0., 100.]), standardized_extent=array([  0, 105,   0,  68]), goal_width=9.6, goal_length=1.9, six_yard_width=26.4, six_yard_length=5.8, penalty_area_width=57.8, penalty_area_length=17.0, corner_diameter=2.0, circle_diameter=18.3, goal_bottom=45.2, goal_top=54.8, six_yard_left=5.8, six_yard_right=94.2, six_yard_bottom=36.8, six_yard_top=63.2, penalty_spot_distance=11.5, penalty_left=11.5, penalty_right=88.5, penalty_area_left=17.0, penalty_area_right=83.0, penalty_area_bottom=21.1, penalty_area_top=78.9, circle_diameter_length=17.42857142857143, circle_diameter_width=26.91176470588235, corner_diameter_length=1.9047619047619049, corner_diameter_width=2.941176470588235, arc1_theta1=np.float64(297.78743103834), arc1_theta2=np.float64(62.212568961660004), arc2_theta1=np.float64(117.78743103834), arc2_theta2=np.float64(242.21256896166), x_markings_sorted=array([  0. ,   5.8,  11.5,  17. ,  50. ,  83. ,  88.5,  94.2, 100. ]), y_markings_sorted=array([  0. ,  21.1,  36.8,  45.2,  54.8,  63.2,  78.9, 100. ]), positional_x=array([  0. ,  17. ,  33.5,  50. ,  66.5,  83. , 100. ]), positional_y=array([  0. ,  21.1,  36.8,  63.2,  78.9, 100. ]), stripe_locations=array([  0.  ,   5.8 ,  11.4 ,  17.  ,  22.6 ,  28.08,  33.56,  39.04,
#         44.52,  50.  ,  55.48,  60.96,  66.44,  71.92,  77.4 ,  83.  ,
#         88.6 ,  94.2 , 100.  ]), position_line4=PositionLine4(GK=Coordinate(x=11.5, y=50.0, x_flip=88.5, y_flip=50.0, x_half=2.9, y_half=50.0, x_half_flip=97.1, y_half_flip=50.0), RB=Coordinate(x=26.9, y=12.5, x_flip=73.1, y_flip=87.5, x_half=11.160000000000002, y_half=12.5, x_half_flip=88.84, y_half_flip=87.5), RCB=Coordinate(x=26.9, y=37.5, x_flip=73.1, y_flip=62.5, x_half=11.160000000000002, y_half=37.5, x_half_flip=88.84, y_half_flip=62.5), LCB=Coordinate(x=26.9, y=62.5, x_flip=73.1, y_flip=37.5, x_half=11.160000000000002, y_half=62.5, x_half_flip=88.84, y_half_flip=37.5), LB=Coordinate(x=26.9, y=87.5, x_flip=73.1, y_flip=12.5, x_half=11.160000000000002, y_half=87.5, x_half_flip=88.84, y_half_flip=12.5), RWB=Coordinate(x=42.3, y=12.5, x_flip=57.7, y_flip=87.5, x_half=19.42, y_half=12.5, x_half_flip=80.58, y_half_flip=87.5), RDM=Coordinate(x=42.3, y=37.5, x_flip=57.7, y_flip=62.5, x_half=19.42, y_half=37.5, x_half_flip=80.58, y_half_flip=62.5), LDM=Coordinate(x=42.3, y=62.5, x_flip=57.7, y_flip=37.5, x_half=19.42, y_half=62.5, x_half_flip=80.58, y_half_flip=37.5), LWB=Coordinate(x=42.3, y=87.5, x_flip=57.7, y_flip=12.5, x_half=19.42, y_half=87.5, x_half_flip=80.58, y_half_flip=12.5), RM=Coordinate(x=57.7, y=12.5, x_flip=42.3, y_flip=87.5, x_half=27.680000000000003, y_half=12.5, x_half_flip=72.32, y_half_flip=87.5), RCM=Coordinate(x=57.7, y=37.5, x_flip=42.3, y_flip=62.5, x_half=27.680000000000003, y_half=37.5, x_half_flip=72.32, y_half_flip=62.5), LCM=Coordinate(x=57.7, y=62.5, x_flip=42.3, y_flip=37.5, x_half=27.680000000000003, y_half=62.5, x_half_flip=72.32, y_half_flip=37.5), LM=Coordinate(x=57.7, y=87.5, x_flip=42.3, y_flip=12.5, x_half=27.680000000000003, y_half=87.5, x_half_flip=72.32, y_half_flip=12.5), RW=Coordinate(x=73.1, y=12.5, x_flip=26.900000000000006, y_flip=87.5, x_half=35.940000000000005, y_half=12.5, x_half_flip=64.06, y_half_flip=87.5), RAM=Coordinate(x=73.1, y=37.5, x_flip=26.900000000000006, y_flip=62.5, x_half=35.940000000000005, y_half=37.5, x_half_flip=64.06, y_half_flip=62.5), LAM=Coordinate(x=73.1, y=62.5, x_flip=26.900000000000006, y_flip=37.5, x_half=35.940000000000005, y_half=62.5, x_half_flip=64.06, y_half_flip=37.5), LW=Coordinate(x=73.1, y=87.5, x_flip=26.900000000000006, y_flip=12.5, x_half=35.940000000000005, y_half=87.5, x_half_flip=64.06, y_half_flip=12.5), RCF=Coordinate(x=88.5, y=37.5, x_flip=11.5, y_flip=62.5, x_half=44.2, y_half=37.5, x_half_flip=55.8, y_half_flip=62.5), LCF=Coordinate(x=88.5, y=62.5, x_flip=11.5, y_flip=37.5, x_half=44.2, y_half=62.5, x_half_flip=55.8, y_half_flip=37.5)), position_line5=PositionLine5(GK=Coordinate(x=11.5, y=50.0, x_flip=88.5, y_flip=50.0, x_half=2.9, y_half=50.0, x_half_flip=97.1, y_half_flip=50.0), RB=Coordinate(x=26.9, y=10.0, x_flip=73.1, y_flip=90.0, x_half=11.160000000000002, y_half=10.0, x_half_flip=88.84, y_half_flip=90.0), RCB=Coordinate(x=26.9, y=30.0, x_flip=73.1, y_flip=70.0, x_half=11.160000000000002, y_half=30.0, x_half_flip=88.84, y_half_flip=70.0), CB=Coordinate(x=26.9, y=50.0, x_flip=73.1, y_flip=50.0, x_half=11.160000000000002, y_half=50.0, x_half_flip=88.84, y_half_flip=50.0), LCB=Coordinate(x=26.9, y=70.0, x_flip=73.1, y_flip=30.0, x_half=11.160000000000002, y_half=70.0, x_half_flip=88.84, y_half_flip=30.0), LB=Coordinate(x=26.9, y=90.0, x_flip=73.1, y_flip=10.0, x_half=11.160000000000002, y_half=90.0, x_half_flip=88.84, y_half_flip=10.0), RWB=Coordinate(x=42.3, y=10.0, x_flip=57.7, y_flip=90.0, x_half=19.42, y_half=10.0, x_half_flip=80.58, y_half_flip=90.0), RDM=Coordinate(x=42.3, y=30.0, x_flip=57.7, y_flip=70.0, x_half=19.42, y_half=30.0, x_half_flip=80.58, y_half_flip=70.0), CDM=Coordinate(x=42.3, y=50.0, x_flip=57.7, y_flip=50.0, x_half=19.42, y_half=50.0, x_half_flip=80.58, y_half_flip=50.0), LDM=Coordinate(x=42.3, y=70.0, x_flip=57.7, y_flip=30.0, x_half=19.42, y_half=70.0, x_half_flip=80.58, y_half_flip=30.0), LWB=Coordinate(x=42.3, y=90.0, x_flip=57.7, y_flip=10.0, x_half=19.42, y_half=90.0, x_half_flip=80.58, y_half_flip ...

# %%
pitch.dim.positional_x
# Out:
# array([  0. ,  17. ,  33.5,  50. ,  66.5,  83. , 100. ])

# %%
pitch.dim.positional_y
# Out:
# array([  0. ,  21.1,  36.8,  63.2,  78.9, 100. ])

# %%
fig, ax = plt.subplots(figsize = (16,9))
pitch.draw(ax=ax)

ax.plot([17,17],[ax.get_ylim()[0],ax.get_ylim()[1]],ls=":",color="red")
ax.plot([33.5,33.5],[ax.get_ylim()[0],ax.get_ylim()[1]],ls=":",color="red")
ax.plot([50,50],[ax.get_ylim()[0],ax.get_ylim()[1]],ls=":",color="red")
ax.plot([66.5,66.5],[ax.get_ylim()[0],ax.get_ylim()[1]],ls=":",color="red")
ax.plot([83,83],[ax.get_ylim()[0],ax.get_ylim()[1]],ls=":",color="red")



ax.plot([ax.get_xlim()[0],ax.get_xlim()[1]],[21.1,21.1],ls=":",color="red")
#ax.plot([ax.get_xlim()[0],ax.get_xlim()[1]],[36.8,36.8],ls=":",color="red")
#ax.plot([ax.get_xlim()[0],ax.get_xlim()[1]],[63.2,63.2],ls=":",color="red")
ax.plot([ax.get_xlim()[0],ax.get_xlim()[1]],[78.9,78.9],ls=":",color="red")

# %%
zone_areas = {
    'zone_1':{
        'x_lower_bound': 0, 'x_upper_bound': 17,
        'y_lower_bound': 78.9, 'y_upper_bound': 100,
    },
    'zone_2':{
        'x_lower_bound': 0, 'x_upper_bound': 17,
        'y_lower_bound': 21.1, 'y_upper_bound': 78.9,
    },
    'zone_3':{
        'x_lower_bound': 0, 'x_upper_bound': 17,
        'y_lower_bound': 0, 'y_upper_bound': 21.1,
    },
    'zone_4':{
        'x_lower_bound': 17, 'x_upper_bound': 33.5,
        'y_lower_bound': 78.9, 'y_upper_bound': 100,
    },
    'zone_5':{
        'x_lower_bound': 17, 'x_upper_bound': 33.5,
        'y_lower_bound': 21.1, 'y_upper_bound': 78.9,
    },
    'zone_6':{
        'x_lower_bound': 17, 'x_upper_bound': 33.5,
        'y_lower_bound': 0, 'y_upper_bound': 21.1,
    },
    'zone_7':{
        'x_lower_bound': 33.5, 'x_upper_bound': 50,
        'y_lower_bound': 78.9, 'y_upper_bound': 100,
    },
    'zone_8':{
        'x_lower_bound': 33.5, 'x_upper_bound': 50,
        'y_lower_bound': 21.1, 'y_upper_bound': 78.9,
    },
    'zone_9':{
        'x_lower_bound': 33.5, 'x_upper_bound': 50,
        'y_lower_bound': 0, 'y_upper_bound': 21.1,
    },
    'zone_10':{
        'x_lower_bound': 50, 'x_upper_bound': 66.5,
        'y_lower_bound': 78.9, 'y_upper_bound': 100,
    },
    'zone_11':{
        'x_lower_bound': 50, 'x_upper_bound': 66.5,
        'y_lower_bound': 21.1, 'y_upper_bound': 78.9,
    },
    'zone_12':{
        'x_lower_bound': 50, 'x_upper_bound': 66.5,
        'y_lower_bound': 0, 'y_upper_bound': 21.1,
    },
    'zone_13':{
        'x_lower_bound': 66.5, 'x_upper_bound': 83,
        'y_lower_bound': 78.9, 'y_upper_bound': 100,
    },
    'zone_14':{
        'x_lower_bound': 66.5, 'x_upper_bound': 83,
        'y_lower_bound': 21.1, 'y_upper_bound': 78.9,
    },
    'zone_15':{
        'x_lower_bound': 66.5, 'x_upper_bound': 83,
        'y_lower_bound': 0, 'y_upper_bound': 21.1,
    },
    'zone_16':{
        'x_lower_bound': 83, 'x_upper_bound': 100,
        'y_lower_bound': 78.9, 'y_upper_bound': 100,
    },
    'zone_17':{
        'x_lower_bound': 83, 'x_upper_bound': 100,
        'y_lower_bound': 21.1, 'y_upper_bound': 78.9,
    },
    'zone_18':{
        'x_lower_bound': 83, 'x_upper_bound': 100,
        'y_lower_bound': 0, 'y_upper_bound': 21.1,
    }
}

# %%
def assign_shot_zone(x,y):
    '''
    This function returns the zone based on the x & y coordinates of the shot
    taken.
    Args:
        - x (float): the x position of the shot based on a vertical grid.
        - y (float): the y position of the shot based on a vertical grid.
    '''

    global zone_areas

    # Conditions

    for zone in zone_areas:
        if (x >= zone_areas[zone]['x_lower_bound']) & (x <= zone_areas[zone]['x_upper_bound']):
            if (y >= zone_areas[zone]['y_lower_bound']) & (y <= zone_areas[zone]['y_upper_bound']):
                return zone

# %%
fig = plt.figure(figsize = (16,9), dpi = 100)
ax = plt.subplot(111)
pitch = Pitch(
    pitch_type='opta',
    axis=True, 
    label=True, 
    tick=True,
    goal_type='box'
)
pitch.draw(ax = ax)

for zone in zone_areas.keys():
    ax.text(x=zone_areas[zone]['x_upper_bound'] - 8, 
            y=zone_areas[zone]['y_upper_bound'] - 10,
            s=zone, ha='center',va='center')

for coordenate in pitch.dim.positional_x:
    ax.plot([coordenate, coordenate], [ax.get_ylim()[0], ax.get_ylim()[1]], ls=':', color='red')

for coordenate in [21.1,78.9]:
    ax.plot([ax.get_ylim()[0], ax.get_ylim()[1]], [coordenate, coordenate], ls=':', color='red')
